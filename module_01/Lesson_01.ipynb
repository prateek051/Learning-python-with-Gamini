# %%
# first programming line in python
#output function -> print()
print("Hello world")
# Out:
# Hello world

# %%
#variables in python 
# The = sign isn't "equals like in math."
# It's the "assignment" operator.
# It means: "Put the thing on the right... into the box labeled on the left."

my_name = "Prateek" # my_name -> is variable and "prateek" is value
my_city = "Bangalore"

# f-string
print(f"my name is {my_name}, and i live in {my_city}")
# Out:
# my name is Prateek, and i live in Bangalore

# %%
#lesson_01 assignment

student_name = "Prateek"
learning_goal = "AI engineer"

#f-string
print(f"my name is {student_name}, and my life goal is to become {learning_goal}")
# Out:
# my name is Prateek, and my life goal is to become AI engineer
