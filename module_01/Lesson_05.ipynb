# %%
# Lists in python 
# A variable (a single box)
my_name = "Prateek"

# A list (a shelf)
# This is am empty list, like an empty shelf.
my_shopping_list = []

# This is a list that starts with items in it.
# We separate each item with a comma.
my_friends = ["Rohan", "Priya", "David", "Sonia"]

# In programming we always start counting from zero.
print(my_friends[0])
print(my_friends[1])
print(my_friends[2])

# all list methods

# append(): Adds an element to the end of the list.
my_friends.append("Raju")
print(my_friends)


# copy(): Returns a shallow copy of the list.
my_friends_2 = my_friends.copy()
print(my_friends_2)

# clear(): Removes all elements from the list.

# count(): Returns the number of times a specified element appears in the list.
my_friends_2_count = my_friends_2.count("Rohan") # number of time an element is present
print(my_friends_2_count)

# extend(): Adds elements from another list to the end of the current list.
# index(): Returns the index of the first occurrence of a specified element.
# insert(): Inserts an element at a specified position.
# pop(): Removes and returns the element at the specified position (or the last element if no index is specified).
# remove(): Removes the first occurrence of a specified element.
# reverse(): Reverses the order of the elements in the list.
# sort(): Sorts the list in ascending order (by default).
# Out:
# Rohan
# Priya
# David
# ['Rohan', 'Priya', 'David', 'Sonia', 'Raju']
# ['Rohan', 'Priya', 'David', 'Sonia', 'Raju']
# 1

# %%
# lesson_05 assignement - Guest list

#empty list
guest_list = []

# adding the elements
guest_list.append("Alice")
guest_list.append("Bob")
guest_list.append("Charlie")

#printing the guest list
print(guest_list)

# Removing the guest form the list
guest_list.remove("Charlie")

#adding to list
guest_list.append("Diana")

#printing the guest names

print(f"The first guest is : {guest_list[0]}\nThe second guest is : {guest_list[1]}\nThe third guest is : {guest_list[2]}")

# The final list
print(guest_list)
# Out:
# ['Alice', 'Bob', 'Charlie']
# The first guest is : Alice
# The second guest is : Bob
# The third guest is : Diana
# ['Alice', 'Bob', 'Diana']
