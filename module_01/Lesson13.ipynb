# %%
#Reading and writing files
# Let's write a simple note
# "w" means Write (Overwrites existing file!)
with open("my_notes.txt", "w") as file:
    file.write("This is my first saved file!\n")
    file.write("I can write mulitple lines.\n")

print("File saved successfully.")
# Out:
# File saved successfully.

# %%
# Reading from the a file
# "r" means Read
with open("my_notes.txt", "r") as file:
    # .read() pulls the whole file into a string variable
    content = file.read()

print("---Here is what was in the file---")
print(content)
# Out:
# ---Here is what was in the file---
# This is my first saved file!
# I can write mulitple lines.

# %%
#Permanent Diary
entry = input("Write a line for your diary: ")
with open("diary.txt", "a") as file:
    # adding the user input to the file
    file.write(f"{entry}\n")

with open("diary.txt", "r") as file:
    # reading the diary.txt file
   diary_file =  file.read()

print("---Here is what was in the file---")
print(diary_file)
# Out:
# ---Here is what was in the file---
# This is my first line in a diary
# i created my first diary
# this is checking the read file
# yes
